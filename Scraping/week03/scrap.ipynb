# %%
import pandas as pd
import bs4
import requests

# %%
page = 1
name = []
price = []
while page <= 5:
    dataset = requests.get('https://www.checkraka.com/car/?fuel_type=4078&quicksearch_order=306,DESC-326,ASC&page=' + str(page))
    soup = bs4.BeautifulSoup(dataset.text)
    for c in soup.find_all('div',{'class':'content c158'}):
        name.append(c.find('div',{'class':'data'}).find('a').text)
        price.append(int(c.find('div',{'class':'price'}).text.split()[0].replace(',','')))
    page += 1 

table = pd.DataFrame([name,price]).transpose()
table.columns = ['Name_1','Price']

table[['Name', 'Year']] = table['Name_1'].str.split('ปี', expand=True)
table = table.drop(['Name_1'], axis = 1)
table = table.set_index('Name')
table
# Out:
#                                                        Price   Year
# Name
# VOLT FOR-TWO CLASSIC                                  325000   2022
# VOLT FOR-TWO TOP                                      355000   2022
# VOLT FOR-FOUR CLSASIC                                 385000   2022
# VOLT FOR-FOUR TOP                                     415000   2022
# NETA V EV                                             549000   2022
# MINE MT 30 EV Mini Truck                              748500   2022
# MINE MT 30 Pastel Edition                             766500   2022
# MG ZS EV D                                            949000   2022
# MG ZS EV X                                           1023000   2022
# BYD ATTO 3                                           1199900   2022
# ORA Good Cat GT                                      1286000   2022
# Mini Cooper SE Electric Collection Edition           2459000   2022
# Volvo C40 RECHARGE PURE ELECTRIC                     2690000   2022
# BMW i 4 eDrive40 M Sport                             4499000   2022
# BMW i 4 M50                                          4999000   2022
# BMW i iX xDrive40                                    4999000   2022
# BMW i 7 xDrive60 M Sport (First Edition)             7599000   2022
# BMW i 7 xDrive60 M Sport                             7849000   2022
# Mercedes-benz EQ EQS 450+ AMG Premium                8570000   2022
# BMW i 7 xDrive60 M Sport Gran Lusso                  8599000   2022
# Mercedes-benz EQ EQS 450+ Edition 1                  8870000   2022
# Land Rover Range Rover 3.0 Petrol Plug-In Hybri...  11499000   2022
# Land Rover Range Rover 3.0 Petrol Plug-In Hybri...  11999000   2022
# Land Rover Range Rover 3.0 Petrol Plug-In Hybri...  15999000   2022
# Ferrari 296 GTB                                     21900000   2022
# Ferrari 296 GTS                                     25290000   2022
# ORA Good Cat 400 TECH                                 763000   2021
# MG EP Plus อีพี                                       771000   2021
# ORA Good Cat 400 PRO                                  828500   2021
# ORA Good Cat 500 ULTRA                                959000   2021
# Nissan LEAF EV                                       1990000   2021
# Volvo XC40 RECHARGE Pure Electric                    2590000   2021
# BMW i X3 M Sport                                     3499000   2021
# BMW i X xDrive50 Sport                               5999000   2021
# Porsche Taycan RWD                                   6390000   2021
# Audi e-tron GT quattro                               6599000   2021
# Audi e-tron GT quattro Performance                   6799000   2021
# Audi RS e-tron GT quattro                            9599000   2021
# Mini Cooper SE                                       2290000   2020
# Lexus UX 300e                                        3490000   2020
# Audi e-tron Sportback 55 quattro S line              5499000   2020
# Porsche Taycan 4S                                    7100000   2020
# Porsche Taycan 4S Plus                               7556500   2020
# Porsche Taycan Turbo                                 9900000   2020
# Porsche Taycan Turbo S                              11700000   2020
# KIA Soul EV MY2019 โซล                               2387000   2019
# Audi e-tron 55 quattro 2019                          5299000   2019
# Jaguar I-PACE S Electric ไอเพซ                       5500000   2019
# BMW i 8 Roadster                                    12999000   2018
